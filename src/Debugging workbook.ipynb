# %%
import os

file = open('pdb_f/2EIE.pdb', 'r')

file_lines = file.readlines()

# %%
lines = [line for line in file_lines if 'ATOM' in line]
lines = [line for line in lines if not 'REMARK' in line]

# %%
len(lines)
# Out:
# 4830

# %%
lines[2050]
# Out:
# 'ATOM   2051  OH  TYR A 272      44.331  31.065  18.623  1.00  5.25           O  \n'

# %%
lines[2045]
# Out:
# 'ATOM   2046  CD1 TYR A 272      46.169  28.297  20.181  1.00  6.03           C  \n'

# %%
file_1 = open('pdb_f/scwrl_out/2EIE_1_out.pdb', 'r')

file_lines_1 = file_1.readlines()

# %%
lines = [line for line in file_lines_1 if 'ATOM' in line]
lines = [line for line in lines if not 'REMARK' in line]

# %%
lines[2050]
# Out:
# 'ATOM   2051  CE2 TYR A 272      45.106  28.933  19.518  1.00                 C  \n'

# %%
lines[2045]
# Out:
# 'ATOM   2046  OH  TYR A 272      42.830  29.230  18.823  1.00                 O  \n'
