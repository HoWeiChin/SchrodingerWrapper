# %%
from scipy.spatial import distance_matrix
from rdkit.Chem.rdmolops import GetAdjacencyMatrix
from rdkit.Chem.rdmolfiles import MolFromPDBFile
import os

# %%
complex_pdb_path = '/home/howc/PycharmProjects/pythonProject2/src/protein_ligand_pdb/CYP3A4.3_2730_complex.pdb'

complex_mol = MolFromPDBFile(complex_pdb_path)
type(complex_mol)
# Out:
# NoneType
